# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('placement.csv')

# %%
df
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 0            0   6.8  123.0          1
# 1            1   5.9  106.0          0
# 2            2   5.3  121.0          0
# 3            3   7.4  132.0          1
# 4            4   5.8  142.0          0
# ..         ...   ...    ...        ...
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1
#
# [100 rows x 4 columns]

# %%
df.dropna().shape
# Out:
# (100, 4)

# %%
df = df.iloc[:, 1:]
df
# Out:
#     cgpa     iq  placement
# 0    6.8  123.0          1
# 1    5.9  106.0          0
# 2    5.3  121.0          0
# 3    7.4  132.0          1
# 4    5.8  142.0          0
# ..   ...    ...        ...
# 95   4.3  200.0          0
# 96   4.4   42.0          0
# 97   6.7  182.0          1
# 98   6.3  103.0          1
# 99   6.2  113.0          1
#
# [100 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
plt.scatter(df['cgpa'], df['iq'], c = df['placement'])

# %%
X = df.iloc[:, 0:2]
y = df.iloc[:, 2]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %%
clf.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = clf.predict(X_test)

# %%
y_test
# Out:
# 69    1
# 18    0
# 81    0
# 37    1
# 39    0
# 78    0
# 96    0
# 64    1
# 71    1
# 91    1
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.9

# %%
import sys
!"{sys.executable}" -m pip install mlxtend
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: mlxtend in C:\Users\Tafsir Khan\AppData\Roaming\Python\Python313\site-packages (0.25.0)
# Requirement already satisfied: scipy>=1.16.3 in C:\Users\Tafsir Khan\AppData\Roaming\Python\Python313\site-packages (from mlxtend) (1.17.1)
# Requirement already satisfied: numpy>=2.3.5 in C:\Users\Tafsir Khan\AppData\Roaming\Python\Python313\site-packages (from mlxtend) (2.4.4)
# Requirement already satisfied: pandas>=2.3.3 in C:\Users\Tafsir Khan\AppData\Roaming\Python\Python313\site-packages (from mlxtend) (3.0.3)
# Requirement already satisfied: scikit-learn>=1.8.0 in C:\Users\Tafsir Khan\AppData\Roaming\Python\Python313\site-packages (from mlxtend) (1.8.0)
# Requirement already satisfied: matplotlib>=3.10.8 in C:\Users\Tafsir Khan\AppData\Roaming\Python\Python313\site-packages (from mlxtend) (3.10.9)
# Requirement already satisfied: joblib>=1.5.2 in C:\Users\Tafsir Khan\AppData\Roaming\Python\Python313\site-packages (from mlxtend) (1.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\Tafsir Khan\AppData\Roaming\Python\Python313\site-packages (from matplotlib>=3.10.8->mlxtend) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\Tafsir Khan\AppData\Roaming\Python\Python313\site-packages (from matplotlib>=3.10.8->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\Tafsir Khan\AppData\Roaming\Python\Python313\site-packages (from matplotlib>=3.10.8->mlxtend) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\Tafsir Khan\AppData\Roaming\Python\Python313\site-packages (from matplotlib>=3.10.8->mlxtend) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in C:\Users\Tafsir Khan\AppData\Roaming\Python\Python313\site-packages (from matplotlib>=3.10.8->mlxtend) (26.2)
# Requirement already satisfied: pillow>=8 in C:\Users\Tafsir Khan\AppData\Roaming\Python\Python313\site-packages (from matplotlib>=3.10.8->mlxtend) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\Tafsir Khan\AppData\Roaming\Python\Python313\site-packages (from matplotlib>=3.10.8->mlxtend) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\Tafsir Khan\AppData\Roaming\Python\Python313\site-packages (from matplotlib>=3.10.8->mlxtend) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\Tafsir Khan\AppData\Roaming\Python\Python313\site-packages (from pandas>=2.3.3->mlxtend) (2026.2)
# Requirement already satisfied: six>=1.5 in C:\Users\Tafsir Khan\AppData\Roaming\Python\Python313\site-packages (from python-dateutil>=2.7->matplotlib>=3.10.8->mlxtend) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.2.0 in C:\Users\Tafsir Khan\AppData\Roaming\Python\Python313\site-packages (from scikit-learn>=1.8.0->mlxtend) (3.6.0)
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: C:\Program Files\Python313\python.exe -m pip install --upgrade pip

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(X_train, y_train.values,
                                clf=clf, legend=2)
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(clf, open('model.pkl', 'wb'))
